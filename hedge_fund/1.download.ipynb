# %%
import pandas as pd
from yahooquery import Ticker

# %%
df_list = pd.read_csv('data/stock_list.csv')
df_list
# Out:
#        No. Ticker                                            Company  \
# 0        1      A                          Agilent Technologies Inc.
# 1        2     AA                                         Alcoa Corp
# 2        3    AAA                    AXS First Priority CLO Bond ETF
# 3        4   AAAU                    Goldman Sachs Physical Gold ETF
# 4        5   AACG                          ATA Creativity Global ADR
# ...    ...    ...                                                ...
# 9497  9498   ZVSA                           ZyVersa Therapeutics Inc
# 9498  9499    ZWS                    Zurn Elkay Water Solutions Corp
# 9499  9500   ZYME                                   Zymeworks BC Inc
# 9500  9501   ZYXI                                          Zynex Inc
# 9501  9502    ZZZ  Cyber Hornet S&P 500 and Bitcoin 75 /25 Strate...
#
#                   Sector                        Industry Country Market Cap  \
# ...

# %%
df_industry = df_list[(df_list['Sector'] == 'Utilities') & (df_list['Country'] == 'USA')]
df_industry
# Out:
#        No. Ticker                               Company     Sector  \
# 112    113    ADN      Advent Technologies Holdings Inc  Utilities
# 132    133    AEE                          Ameren Corp.  Utilities
# 146    147    AEP  American Electric Power Company Inc.  Utilities
# 149    150    AES                             AES Corp.  Utilities
# 197    198    AGR                          Avangrid Inc  Utilities
# ...    ...    ...                                   ...        ...
# 8988  8989    VST                           Vistra Corp  Utilities
# 9097  9098    WEC                  WEC Energy Group Inc  Utilities
# 9213  9214   WTRG               Essential Utilities Inc  Utilities
# 9264  9265    XEL                     Xcel Energy, Inc.  Utilities
# 9421  9422   YORW                        York Water Co.  Utilities
#
#                                      Industry Country Market Cap    P/E  \
# 112                     Utilities - Renewable     USA     11.42M   0.00
# ...

# %%
tickers = Ticker(df_industry['Ticker'].values, asynchronous=True)

# Default period = ytd, interval = 1d
df_stock = tickers.history(start='2023-03-01',end='2024-05-01',interval='1d')

df_stock
# Out:
#                         open       high        low      close  volume  \
# symbol date
# ADN    2023-03-01  54.900002  54.900002  51.900002  52.200001    9230
#        2023-03-02  53.099998  53.099998  51.000000  51.599998    7003
#        2023-03-03  51.900002  53.400002  51.000000  53.400002   10671
#        2023-03-06  53.400002  54.050999  51.599998  52.200001    8059
#        2023-03-07  52.200001  53.049000  51.000000  51.599998    7130
# ...                      ...        ...        ...        ...     ...
# YORW   2024-04-24  35.500000  35.700001  35.119999  35.529999   39400
#        2024-04-25  35.330002  35.560001  35.099998  35.369999   44700
#        2024-04-26  35.580002  35.580002  35.270000  35.369999   35400
#        2024-04-29  35.389999  35.660000  35.349998  35.520000   38600
#        2024-04-30  35.139999  35.650002  35.119999  35.509998   53800
#
#                     adjclose  dividends  splits
# symbol date
# ADN    2023-03-01  52.200001        0.0     0.0
# ...

# %%
df_prices = df_stock['adjclose'].unstack(level=0)
df_prices.index = pd.to_datetime(df_prices.index)
df_prices.dropna(axis=1,inplace=True)
df_prices
# Out:
# symbol            ADN        AEE        AEP        AES        AGR    ALCE  \
# date
# 2023-03-01  52.200001  77.833527  82.796310  23.525192  36.142548  10.200
# 2023-03-02  51.599998  79.110909  84.359062  23.534746  36.787613  10.205
# 2023-03-03  53.400002  80.417099  85.413658  23.974112  37.280895  10.210
# 2023-03-06  52.200001  80.532349  85.682106  23.878599  37.413712  10.220
# 2023-03-07  51.599998  79.178139  84.972641  23.410582  36.759155  10.230
# ...               ...        ...        ...        ...        ...     ...
# 2024-04-24   4.980000  74.709999  86.370003  17.201746  37.020000   0.317
# 2024-04-25   4.914000  74.760002  86.860001  16.964069  36.549999   0.330
# 2024-04-26   4.548000  73.660004  85.260002  17.043295  36.380001   0.344
# 2024-04-29   4.428000  74.349998  86.669998  17.687000  36.630001   0.345
# 2024-04-30   3.741000  73.870003  86.029999  17.900000  36.529999   0.341
#
# ...

# %%
df_prices.to_csv('stock_prices.csv')
